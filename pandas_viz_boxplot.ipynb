# %%
import pandas as pd
# %matplotlib inline
pd.__version__
# Out:
# '0.24.2'

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
df.sample(10)
# Out:
#     manufacturer            model  displ  year  cyl     trans drv  cty  hwy  \
# 194       toyota          corolla    1.8  1999    4  auto(l4)   f   24   33
# 222   volkswagen       new beetle    1.9  1999    4  auto(l4)   f   29   41
# 105        honda            civic    1.8  2008    4  auto(l5)   f   25   36
# 88          ford  f150 pickup 4wd    5.4  1999    8  auto(l4)   4   11   15
# 175       toyota      4runner 4wd    3.4  1999    6  auto(l4)   4   15   19
# 154      pontiac       grand prix    3.1  1999    6  auto(l4)   f   18   26
# 155      pontiac       grand prix    3.8  1999    6  auto(l4)   f   16   26
# 8           audi       a4 quattro    1.8  1999    4  auto(l5)   4   16   25
# 43         dodge      caravan 2wd    3.3  2008    6  auto(l4)   f   11   17
# 157      pontiac       grand prix    3.8  2008    6  auto(l4)   f   18   28
#
#     fl       class
# 194  r     compact
# 222  d  subcompact
# 105  r  subcompact
# 88   r      pickup
# 175  r         suv
# 154  r     midsize
# 155  p     midsize
# 8    p     compact
# 43   e     minivan
# 157  r     midsize

# %%
df.cty.plot.box()

# %%
df.boxplot()

# %%
df[['cty', 'hwy']].plot.box()

# %%
df[['cty', 'hwy']].boxplot()

# %%
df.boxplot(column=['cty', 'hwy']);

# %%
df.boxplot(column=['cty', 'hwy'], by='drv');

# %%
df.boxplot(column=['cty', 'hwy'], by='drv', grid=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb805acc588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb805a2c080>],
#       dtype=object)

# %%
df.boxplot(column='cty', by=['class', 'drv'])

# %%
df.boxplot(column='cty', by=['class', 'drv'], rot=90, grid=False)

# %%
df.boxplot(column='cty', by=['class', 'drv'], vert=False, grid=False)

# %%
df.boxplot(column=['cty', 'hwy'], by=['class', 'drv'], vert=False, grid=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb8058657b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb805811cf8>],
#       dtype=object)

# %%
df.boxplot(column=['cty', 'hwy'], by=['class', 'drv'], vert=False, grid=False, figsize=(10, 5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb80559f8d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb80550b0f0>],
#       dtype=object)
